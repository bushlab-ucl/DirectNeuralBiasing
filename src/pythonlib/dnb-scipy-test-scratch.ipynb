# %%
import dnb
from scipy import signal
import matplotlib.pyplot as plt
import numpy as np

# %%
dnb.filters.butterworth(1,20,[1,2,3,2,1])
# Out:
# [0.1268013797508113,
#  0.45154200532911015,
#  0.8771437318726636,
#  1.079640060913105,
#  0.869177409408239]

# %%
dnb.filters.with_bounds([1,10],20,[1,2,3,2,1])
# Out:
# [0.19109804065875705,
#  0.4773441576227357,
#  0.6366353255776908,
#  0.35886846236198083,
#  -0.14765060682830852]

# %%
b, a = signal.butter(2, [1, 2], 'bp', fs=20)
w, h = signal.freqs(b, a)
plt.semilogx(w, 20 * np.log10(abs(h)))
plt.title('Butterworth filter frequency response')
plt.xlabel('Frequency [radians / second]')
plt.ylabel('Amplitude [dB]')
plt.margins(0, 0.1)
plt.grid(which='both', axis='both')
plt.axvline(100, color='green') # cutoff frequency
plt.show()

# %%
signal.lfilter(b,a,[1,2,3,2,1])
# Out:
# array([0.02008337, 0.10468335, 0.27268241, 0.45110107, 0.48816822])
