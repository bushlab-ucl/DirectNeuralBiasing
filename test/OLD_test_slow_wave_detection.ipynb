# %%
# from pathlib import Path
# from time import time
# import math
# import json
# import csv
# import re
# import gc

# from scipy import signal
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd

# import mne
# import direct_neural_biasing as dnb

from brpylib import NsxFile
import os
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## continuous data

# %%
data_file = 'data/Patient02.ns5'
mrk_file = 'data/Patient02_OfflineMrk.mrk'
nsx_file = NsxFile(data_file)

data = nsx_file.getdata()
nsx_file.close()
# Out:
# Patient02.ns5 opened
#
# Patient02.ns5 closed

# %%
data
# Out:
# {'elec_ids': [1],
#  'start_time_s': 0.0,
#  'data_time_s': 2774.0,
#  'downsample': 1,
#  'data': array([[  0.  ,   0.  ,   0.  , ..., -69.  , -69.25, -69.5 ]],
#        dtype=float32),
#  'data_headers': [{'Header': 1, 'Timestamp': 0, 'NumDataPoints': 83220000}],
#  'ExtendedHeaderIndices': [0],
#  'samp_per_s': 30000.0}

# %%
np.shape(data['data'])
# Out:
# (1, 1, 83220000)

# %%
data_cont = data['data'][0][0]  # the [0][0] may be because we're sampling just channel 1 ?
t_offset = int(data['data_time_s'])

# %%
def plot_data_stream_section(data_stream, n, m):
    """
    Plots an n-m section of a 1D integer data stream as a line graph.

    Args:
        data_stream (list or numpy.ndarray): The 1D integer data stream.
        n (int): The starting index (inclusive).
        m (int): The ending index (inclusive).
    """
    section = data_stream[n : m + 1]
    indices = range(n, m + 1)

    plt.figure(figsize=(14, 6))
    plt.plot(indices, section)
    plt.title(f'Data Section {n} to {m}')
    plt.xlabel('Index')
    plt.ylabel('Value')
    plt.grid(True)
    plt.show()

start_t = 2515 + t_offset
end_t = 4515 + t_offset

plot_data_stream_section(data_cont, start_t, end_t)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 24
#      21 start_t = 2515 + t_offset
#      22 end_t = 4515 + t_offset
# ---> 24 plot_data_stream_section(data_cont, start_t, end_t)
#
# Cell In[17], line 10, in plot_data_stream_section(data_stream, n, m)
#       1 def plot_data_stream_section(data_stream, n, m):
#       2     """
#       3     Plots an n-m section of a 1D integer data stream as a line graph.
#       4
#    (...)
#       8         m (int): The ending index (inclusive).
#       9     """
# ---> 10     section = data_stream[n : m + 1]
#      11     indices = range(n, m + 1)
#      13     plt.figure(figsize=(14, 6))
#
# IndexError: invalid index to scalar variable.

# %% [markdown]
# ## .mrk file - offlineSW

# %%
# --- Concise .mrk file parser ---
def parse_mrk_file_concise(filepath):
    """
    Parses a .mrk file into a dictionary (signal_type: [indices]).
    Assumes first line is header, subsequent lines are 'index index signal_type'.
    """
    mrk_data = {}
    with open(filepath, 'r') as f:
        next(f) # Skip header line
        for line in f:
            parts = line.strip().split()
            if len(parts) == 3:
                index = int(parts[0])
                signal_type = parts[2]
                mrk_data.setdefault(signal_type, []).append(index)
    return mrk_data

def plot_marker_with_context(data_stream, marker_index, signal_type, context_window=500, output_dir="marker_plots"):
    """
    Plots a single marker with surrounding data context.
    """
    data_length = len(data_stream)
    plot_start = max(0, marker_index - context_window)
    plot_end = min(data_length - 1, marker_index + context_window)

    section_data = data_stream[plot_start : plot_end + 1]
    section_indices = range(plot_start, plot_end + 1)

    # CORRECTED LINE: Check if the section_data is empty using its length/size
    if len(section_data) == 0: # or if section_data.size == 0: if you're sure it's a numpy array
        print(f"Skipping plot for marker {marker_index} ({signal_type}) due to empty data section.")
        return

    plt.figure(figsize=(14, 6))
    plt.plot(section_indices, section_data, label='Continuous Data', color='blue', linewidth=1.5)

    # Highlight the marker point
    plt.axvline(x=marker_index, color='red', linestyle='--', label=f'Marker: {signal_type}')
    # Ensure the marker_index is within the bounds of data_stream before trying to access it
    if 0 <= marker_index < data_length:
        plt.plot(marker_index, data_stream[marker_index], 'ro', markersize=8, label='Marker Location')
    else:
        print(f"Warning: Marker index {marker_index} is out of bounds for data_stream. Cannot plot marker point.")


    plt.title(f'Signal Type: {signal_type} at Index: {marker_index} (Context: $\pm${context_window})')
    plt.xlabel('Data Index')
    plt.ylabel('Value')
    plt.grid(True, linestyle=':', alpha=0.7)
    plt.legend()
    plt.tight_layout()

    # Save the plot
    os.makedirs(output_dir, exist_ok=True) # Ensure output directory exists
    filename = os.path.join(output_dir, f"{signal_type}_marker_{marker_index}.png")
    plt.savefig(filename)
    plt.close()
    print(f"  Saved plot for marker {marker_index} as {filename}")

# %%
# --- Main Execution ---

# 1. Parse the .mrk file
parsed_markers = parse_mrk_file_concise(mrk_file)
print("\nParsed Markers:")
for signal_type, indices in parsed_markers.items():
    print(f"  {signal_type}: {indices[:5]}... ({len(indices)} total)")

# 2. Plot each marker with context
context_window_size = 500 # Adjust this to change how much data is shown around each marker
print(f"\nGenerating plots with context window of $\pm${context_window_size}...")
for signal_type, indices in parsed_markers.items():
    for marker_index in indices:
        plot_marker_with_context(data_cont, marker_index, signal_type, context_window=context_window_size)

print("\nAll marker plots generated in 'marker_plots' directory.")
# Out:
# Parsed Markers:
#   offlineSW: [3515, 7210, 7897, 14431, 16326]... (208 total)
#
# Generating plots with context window of $\pm$500...
#   Saved plot for marker 3515 as marker_plots\offlineSW_marker_3515.png
#   Saved plot for marker 7210 as marker_plots\offlineSW_marker_7210.png
#   Saved plot for marker 7897 as marker_plots\offlineSW_marker_7897.png
#   Saved plot for marker 14431 as marker_plots\offlineSW_marker_14431.png
#   Saved plot for marker 16326 as marker_plots\offlineSW_marker_16326.png
#   Saved plot for marker 22898 as marker_plots\offlineSW_marker_22898.png
#   Saved plot for marker 34742 as marker_plots\offlineSW_marker_34742.png
#   Saved plot for marker 41220 as marker_plots\offlineSW_marker_41220.png
#   Saved plot for marker 67976 as marker_plots\offlineSW_marker_67976.png
#   Saved plot for marker 104391 as marker_plots\offlineSW_marker_104391.png
#   Saved plot for marker 110861 as marker_plots\offlineSW_marker_110861.png
#   Saved plot for marker 120764 as marker_plots\offlineSW_marker_120764.png
#   Saved plot for marker 123854 as marker_plots\offlineSW_marker_123854.png
#   Saved plot for marker 138989 as marker_plots\offlineSW_marker_138989.png
#   Saved plot for marker 166750 as marker_plots\offlineSW_marker_166750.png
#   Saved plot for marker 167681 as marker_plots\offlineSW_marker_167681.png
#   Saved plot for marker 168638 as marker_plots\offlineSW_marker_168638.png
#   Saved plot for marker 169955 as marker_plots\offlineSW_marker_169955.png
#   Saved plot for marker 171377 as marker_plots\offlineSW_marker_171377.png
#   Saved plot for marker 173178 as marker_plots\offlineSW_marker_173178.png
#   Saved plot for marker 174207 as marker_plots\offlineSW_marker_174207.png
#   Saved plot for marker 175397 as marker_plots\offlineSW_marker_175397.png
#   Saved plot for marker 176849 as marker_plots\offlineSW_marker_176849.png
#   Saved plot for marker 179061 as marker_plots\offlineSW_marker_179061.png
#   Saved plot for marker 180381 as marker_plots\offlineSW_marker_180381.png
#   Saved plot for marker 186519 as marker_plots\offlineSW_marker_186519.png
#   Saved plot for marker 190456 as marker_plots\offlineSW_marker_190456.png
#   Saved plot for marker 192306 as marker_plots\offlineSW_marker_192306.png
#   Saved plot for marker 195262 as marker_plots\offlineSW_marker_195262.png
#   Saved plot for marker 197254 as marker_plots\offlineSW_marker_197254.png
#   Saved plot for marker 202822 as marker_plots\offlineSW_marker_202822.png
#   Saved plot for marker 204704 as marker_plots\offlineSW_marker_204704.png
#   Saved plot for marker 207367 as marker_plots\offlineSW_marker_207367.png
#   Saved plot for marker 208602 as marker_plots\offlineSW_marker_208602.png
#   Saved plot for marker 222301 as marker_plots\offlineSW_marker_222301.png
#   Saved plot for marker 225074 as marker_plots\offlineSW_marker_225074.png
#   Saved plot for marker 249527 as marker_plots\offlineSW_marker_249527.png
#   Saved plot for marker 257752 as marker_plots\offlineSW_marker_257752.png
#   Saved plot for marker 262338 as marker_plots\offlineSW_marker_262338.png
#   Saved plot for marker 278796 as marker_plots\offlineSW_marker_278796.png
#   Saved plot for marker 282035 as marker_plots\offlineSW_marker_282035.png
#   Saved plot for marker 283471 as marker_plots\offlineSW_marker_283471.png
#   Saved plot for marker 289166 as marker_plots\offlineSW_marker_289166.png
#   Saved plot for marker 293516 as marker_plots\offlineSW_marker_293516.png
#   Saved plot for marker 301738 as marker_plots\offlineSW_marker_301738.png
#   Saved plot for marker 326201 as marker_plots\offlineSW_marker_326201.png
#   Saved plot for marker 328392 as marker_plots\offlineSW_marker_328392.png
#   Saved plot for marker 329631 as marker_plots\offlineSW_marker_329631.png
#   Saved plot for marker 331568 as marker_plots\offlineSW_marker_331568.png
#   Saved plot for marker 333284 as marker_plots\offlineSW_marker_333284.png
#   Saved plot for marker 334346 as marker_plots\offlineSW_marker_334346.png
#   Saved plot for marker 337083 as marker_plots\offlineSW_marker_337083.png
#   Saved plot for marker 338621 as marker_plots\offlineSW_marker_338621.png
#   Saved plot for marker 339585 as marker_plots\offlineSW_marker_339585.png
#   Saved plot for marker 341028 as marker_plots\offlineSW_marker_341028.png
#   Saved plot for marker 342563 as marker_plots\offlineSW_marker_342563.png
#   Saved plot for marker 343466 as marker_plots\offlineSW_marker_343466.png
#   Saved plot for marker 345716 as marker_plots\offlineSW_marker_345716.png
#   Saved plot for marker 351130 as marker_plots\offlineSW_marker_351130.png
#   Saved plot for marker 354683 as marker_plots\offlineSW_marker_354683.png
#   Saved plot for marker 360955 as marker_plots\offlineSW_marker_360955.png
#   Saved plot for marker 361802 as marker_plots\offlineSW_marker_361802.png
#   Saved plot for marker 366490 as marker_plots\offlineSW_marker_366490.png
#   Saved plot for marker 369555 as marker_plots\offlineSW_marker_369555.png
#   Saved plot for marker 369996 as marker_plots\offlineSW_marker_369996.png
#   Saved plot for marker 371143 as marker_plots\offlineSW_marker_371143.png
#   Saved plot for marker 371678 as marker_plots\offlineSW_marker_371678.png
#   Saved plot for marker 376481 as marker_plots\offlineSW_marker_376481.png
#   Saved plot for marker 392767 as marker_plots\offlineSW_marker_392767.png
#   Saved plot for marker 405390 as marker_plots\offlineSW_marker_405390.png
#   Saved plot for marker 407884 as marker_plots\offlineSW_marker_407884.png
#   Saved plot for marker 410122 as marker_plots\offlineSW_marker_410122.png
#   Saved plot for marker 432764 as marker_plots\offlineSW_marker_432764.png
#   Saved plot for marker 440901 as marker_plots\offlineSW_marker_440901.png
#   Saved plot for marker 453418 as marker_plots\offlineSW_marker_453418.png
#   Saved plot for marker 459280 as marker_plots\offlineSW_marker_459280.png
#   Saved plot for marker 460763 as marker_plots\offlineSW_marker_460763.png
#   Saved plot for marker 463302 as marker_plots\offlineSW_marker_463302.png
#   Saved plot for marker 474692 as marker_plots\offlineSW_marker_474692.png
#   Saved plot for marker 482118 as marker_plots\offlineSW_marker_482118.png
#   Saved plot for marker 497661 as marker_plots\offlineSW_marker_497661.png
#   Saved plot for marker 500511 as marker_plots\offlineSW_marker_500511.png
#   Saved plot for marker 515894 as marker_plots\offlineSW_marker_515894.png
#   Saved plot for marker 523915 as marker_plots\offlineSW_marker_523915.png
#   Saved plot for marker 546075 as marker_plots\offlineSW_marker_546075.png
#   Saved plot for marker 546703 as marker_plots\offlineSW_marker_546703.png
#   Saved plot for marker 564259 as marker_plots\offlineSW_marker_564259.png
#   Saved plot for marker 573572 as marker_plots\offlineSW_marker_573572.png
#   Saved plot for marker 575157 as marker_plots\offlineSW_marker_575157.png
#   Saved plot for marker 575966 as marker_plots\offlineSW_marker_575966.png
#   Saved plot for marker 577048 as marker_plots\offlineSW_marker_577048.png
#   Saved plot for marker 577852 as marker_plots\offlineSW_marker_577852.png
#   Saved plot for marker 578714 as marker_plots\offlineSW_marker_578714.png
#   Saved plot for marker 580022 as marker_plots\offlineSW_marker_580022.png
#   Saved plot for marker 580960 as marker_plots\offlineSW_marker_580960.png
#   Saved plot for marker 581811 as marker_plots\offlineSW_marker_581811.png
#   Saved plot for marker 582995 as marker_plots\offlineSW_marker_582995.png
#   Saved plot for marker 586644 as marker_plots\offlineSW_marker_586644.png
#   Saved plot for marker 588980 as marker_plots\offlineSW_marker_588980.png
#   Saved plot for marker 594328 as marker_plots\offlineSW_marker_594328.png
#   Saved plot for marker 596862 as marker_plots\offlineSW_marker_596862.png
#   Saved plot for marker 598742 as marker_plots\offlineSW_marker_598742.png
#   Saved plot for marker 601152 as marker_plots\offlineSW_marker_601152.png
#   Saved plot for marker 602610 as marker_plots\offlineSW_marker_602610.png
#   Saved plot for marker 604415 as marker_plots\offlineSW_marker_604415.png
#   Saved plot for marker 607870 as marker_plots\offlineSW_marker_607870.png
#   Saved plot for marker 609261 as marker_plots\offlineSW_marker_609261.png
#   Saved plot for marker 611574 as marker_plots\offlineSW_marker_611574.png
#   Saved plot for marker 613063 as marker_plots\offlineSW_marker_613063.png
#   Saved plot for marker 614972 as marker_plots\offlineSW_marker_614972.png
#   Saved plot for marker 648536 as marker_plots\offlineSW_marker_648536.png
#   Saved plot for marker 657836 as marker_plots\offlineSW_marker_657836.png
#   Saved plot for marker 672713 as marker_plots\offlineSW_marker_672713.png
#   Saved plot for marker 681972 as marker_plots\offlineSW_marker_681972.png
#   Saved plot for marker 694355 as marker_plots\offlineSW_marker_694355.png
#   Saved plot for marker 695153 as marker_plots\offlineSW_marker_695153.png
#   Saved plot for marker 699830 as marker_plots\offlineSW_marker_699830.png
#   Saved plot for marker 704289 as marker_plots\offlineSW_marker_704289.png
#   Saved plot for marker 711971 as marker_plots\offlineSW_marker_711971.png
#   Saved plot for marker 719122 as marker_plots\offlineSW_marker_719122.png
#   Saved plot for marker 719604 as marker_plots\offlineSW_marker_719604.png
#   Saved plot for marker 767853 as marker_plots\offlineSW_marker_767853.png
#   Saved plot for marker 771423 as marker_plots\offlineSW_marker_771423.png
#   Saved plot for marker 780870 as marker_plots\offlineSW_marker_780870.png
#   Saved plot for marker 800563 as marker_plots\offlineSW_marker_800563.png
#   Saved plot for marker 803190 as marker_plots\offlineSW_marker_803190.png
#   Saved plot for marker 823079 as marker_plots\offlineSW_marker_823079.png
#   Saved plot for marker 829506 as marker_plots\offlineSW_marker_829506.png
#   Saved plot for marker 832525 as marker_plots\offlineSW_marker_832525.png
#   Saved plot for marker 841641 as marker_plots\offlineSW_marker_841641.png
#   Saved plot for marker 850332 as marker_plots\offlineSW_marker_850332.png
#   Saved plot for marker 868298 as marker_plots\offlineSW_marker_868298.png
#   Saved plot for marker 871650 as marker_plots\offlineSW_marker_871650.png
#   Saved plot for marker 894558 as marker_plots\offlineSW_marker_894558.png
#   Saved plot for marker 917329 as marker_plots\offlineSW_marker_917329.png
#   Saved plot for marker 938416 as marker_plots\offlineSW_marker_938416.png
#   Saved plot for marker 950665 as marker_plots\offlineSW_marker_950665.png
#   Saved plot for marker 960430 as marker_plots\offlineSW_marker_960430.png
#   Saved plot for marker 961299 as marker_plots\offlineSW_marker_961299.png
#   Saved plot for marker 962360 as marker_plots\offlineSW_marker_962360.png
#   Saved plot for marker 963235 as marker_plots\offlineSW_marker_963235.png
#   Saved plot for marker 964174 as marker_plots\offlineSW_marker_964174.png
#   Saved plot for marker 965407 as marker_plots\offlineSW_marker_965407.png
#   Saved plot for marker 967919 as marker_plots\offlineSW_marker_967919.png
#   Saved plot for marker 970987 as marker_plots\offlineSW_marker_970987.png
#   Saved plot for marker 972534 as marker_plots\offlineSW_marker_972534.png
#   Saved plot for marker 974046 as marker_plots\offlineSW_marker_974046.png
#   Saved plot for marker 974933 as marker_plots\offlineSW_marker_974933.png
#   Saved plot for marker 977250 as marker_plots\offlineSW_marker_977250.png
#   Saved plot for marker 979341 as marker_plots\offlineSW_marker_979341.png
#   Saved plot for marker 980826 as marker_plots\offlineSW_marker_980826.png
#   Saved plot for marker 983157 as marker_plots\offlineSW_marker_983157.png
#   Saved plot for marker 984482 as marker_plots\offlineSW_marker_984482.png
#   Saved plot for marker 985736 as marker_plots\offlineSW_marker_985736.png
#   Saved plot for marker 987127 as marker_plots\offlineSW_marker_987127.png
#   Saved plot for marker 988070 as marker_plots\offlineSW_marker_988070.png
#   Saved plot for marker 988943 as marker_plots\offlineSW_marker_988943.png
#   Saved plot for marker 990756 as marker_plots\offlineSW_marker_990756.png
#   Saved plot for marker 992299 as marker_plots\offlineSW_marker_992299.png
#   Saved plot for marker 994074 as marker_plots\offlineSW_marker_994074.png
#   Saved plot for marker 995378 as marker_plots\offlineSW_marker_995378.png
#   Saved plot for marker 999167 as marker_plots\offlineSW_marker_999167.png
#   Saved plot for marker 1026257 as marker_plots\offlineSW_marker_1026257.png
#   Saved plot for marker 1032666 as marker_plots\offlineSW_marker_1032666.png
#   Saved plot for marker 1033890 as marker_plots\offlineSW_marker_1033890.png
#   Saved plot for marker 1035659 as marker_plots\offlineSW_marker_1035659.png
#   Saved plot for marker 1036027 as marker_plots\offlineSW_marker_1036027.png
#   Saved plot for marker 1036624 as marker_plots\offlineSW_marker_1036624.png
#   Saved plot for marker 1043689 as marker_plots\offlineSW_marker_1043689.png
#   Saved plot for marker 1055158 as marker_plots\offlineSW_marker_1055158.png
#   Saved plot for marker 1056194 as marker_plots\offlineSW_marker_1056194.png
#   Saved plot for marker 1119834 as marker_plots\offlineSW_marker_1119834.png
#   Saved plot for marker 1125183 as marker_plots\offlineSW_marker_1125183.png
#   Saved plot for marker 1145862 as marker_plots\offlineSW_marker_1145862.png
#   Saved plot for marker 1162219 as marker_plots\offlineSW_marker_1162219.png
#   Saved plot for marker 1163289 as marker_plots\offlineSW_marker_1163289.png
#   Saved plot for marker 1164346 as marker_plots\offlineSW_marker_1164346.png
#   Saved plot for marker 1165142 as marker_plots\offlineSW_marker_1165142.png
#   Saved plot for marker 1167068 as marker_plots\offlineSW_marker_1167068.png
#   Saved plot for marker 1170414 as marker_plots\offlineSW_marker_1170414.png
#   Saved plot for marker 1174730 as marker_plots\offlineSW_marker_1174730.png
#   Saved plot for marker 1176267 as marker_plots\offlineSW_marker_1176267.png
#   Saved plot for marker 1178099 as marker_plots\offlineSW_marker_1178099.png
#   Saved plot for marker 1183082 as marker_plots\offlineSW_marker_1183082.png
#   Saved plot for marker 1187660 as marker_plots\offlineSW_marker_1187660.png
#   Saved plot for marker 1189050 as marker_plots\offlineSW_marker_1189050.png
#   Saved plot for marker 1190105 as marker_plots\offlineSW_marker_1190105.png
#   Saved plot for marker 1192242 as marker_plots\offlineSW_marker_1192242.png
#   Saved plot for marker 1198314 as marker_plots\offlineSW_marker_1198314.png
#   Saved plot for marker 1200428 as marker_plots\offlineSW_marker_1200428.png
#   Saved plot for marker 1202041 as marker_plots\offlineSW_marker_1202041.png
#   Saved plot for marker 1218907 as marker_plots\offlineSW_marker_1218907.png
#   Saved plot for marker 1223575 as marker_plots\offlineSW_marker_1223575.png
#   Saved plot for marker 1227019 as marker_plots\offlineSW_marker_1227019.png
#   Saved plot for marker 1227680 as marker_plots\offlineSW_marker_1227680.png
#   Saved plot for marker 1228185 as marker_plots\offlineSW_marker_1228185.png
#   Saved plot for marker 1245950 as marker_plots\offlineSW_marker_1245950.png
#   Saved plot for marker 1255047 as marker_plots\offlineSW_marker_1255047.png
#   Saved plot for marker 1267590 as marker_plots\offlineSW_marker_1267590.png
#   Saved plot for marker 1267998 as marker_plots\offlineSW_marker_1267998.png
#   Saved plot for marker 1324195 as marker_plots\offlineSW_marker_1324195.png
#   Saved plot for marker 1328602 as marker_plots\offlineSW_marker_1328602.png
#   Saved plot for marker 1330038 as marker_plots\offlineSW_marker_1330038.png
#   Saved plot for marker 1330556 as marker_plots\offlineSW_marker_1330556.png
#   Saved plot for marker 1333979 as marker_plots\offlineSW_marker_1333979.png
#   Saved plot for marker 1345704 as marker_plots\offlineSW_marker_1345704.png
#   Saved plot for marker 1379519 as marker_plots\offlineSW_marker_1379519.png
#   Saved plot for marker 1403851 as marker_plots\offlineSW_marker_1403851.png
#
# All marker plots generated in 'marker_plots' directory.
